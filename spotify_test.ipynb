# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import json

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id="db283fe46ff3452ebeecfc328a68fb58",
    client_secret="28d8a27fca2440319df77c97ae50e22e",
    redirect_uri="http://127.0.0.1:8888/callback",
    scope="playlist-modify-public playlist-modify-private"
))

# %%
user_id = sp.me()["id"]

playlist = sp.user_playlist_create(
    user=user_id,
    name="My New Playlist",
    public=False,
    description="Created with the Spotify API!"
)

print(f"Created playlist: {playlist['name']} ({playlist['id']})")
# Out:
# Created playlist: My New Playlist (28w0xJpfQSQayTBHyj5d5X)

# %%
def find_track_id(song_name):
    result = sp.search(q=song_name, type="track", limit=10)
    tracks = result["tracks"]["items"]
    print(json.dunmps(tracks[0]))
    #print([(hit["artist"]["name"], hit["name"]) for hit in tracks])
    return tracks[0]["id"] if tracks else None

# %%
find_track_id("Emptiness Machine")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 find_track_id("Emptiness Machine")
#
# Cell In[10], line 4, in find_track_id(song_name)
#       2 result = sp.search(q=song_name, type="track", limit=10)
#       3 tracks = result["tracks"]["items"]
# ----> 4 print([(hit["artist"]["name"], hit["name"]) for hit in tracks])
#       5 return tracks[0]["id"] if tracks else None
#
# KeyError: 'artist'
